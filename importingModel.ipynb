# %%
from tensorflow.keras.models import load_model
import numpy as np

# %%
my_model = load_model('logsModel.h5')

# %%
from tensorflow import keras

# %%
keras.utils.plot_model(
    my_model,
    to_file="logsModel.png",
    show_shapes=True,
    expand_nested=True,
    dpi=150,
)

# %%
my_model.predict([X[1].tolist()])
# Out:
# 1/1 [==============================] - 0s 76ms/step
# array([[1.]], dtype=float32)
